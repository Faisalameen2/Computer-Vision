# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image-2.png](attachment:image-2.png)
#
# PDF = No.of Pixels / total of pixels
#
# CDF = Go back to the Video, but basically you have to sum as the arrows moves in the above image

# %%
import cv2
import numpy as np
import matplotlib.pyplot  as plt 
#img = cv2.imread("Data/lenna.png")
img = cv2.imread("Data/lenna.png",0)

#img = np.zeros((500,500), np.uint8) #Just for clarification
#cv2.rectangle(img, (0,250), (500,500), (250), -1) #Just for clarification
#cv2.rectangle(img, (0,150), (250,250), (127), -1) #Just for clarification

#b,g,r = cv2.split(img)
#cv2.imshow("b", b)
#cv2.imshow("g", g)
#cv2.imshow("r", r)
#the below code to make histogram for the image
plt.hist(img.ravel(), 255,[0,255]) #ravel: find the pixels of the image, 
                                #255: max number of pixels,
                                #[0,255]: range of histogram diagram
#plt.hist(b.ravel(), 255,[0,255])
#plt.hist(g.ravel(), 255,[0,255])
#plt.hist(r.ravel(), 255,[0,255])

hist = cv2.calcHist(img, [0], None, [255], [0,255])
plt.plot(hist)

plt.show() #when the diagram is showed, the 250000 in the left side is equal to
            #500 * 500, that is what we wrote in np.zeros funtion above
cv2.imshow("img", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
