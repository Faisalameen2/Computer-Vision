# %% [markdown]
# # ![image.png](attachment:image.png)
#
# The above image shows the first step of Haar Cascase, which is Haar-like features, and the Haar is works only on the Gray scale images.
#
# the equation is: summation of black pixels - summation of white pixels. if the value is large, it means there is an edge in this pixel
#
# https://www.mygreatlearning.com/blog/viola-jones-algorithm/

# %%
import cv2

face_cascase = cv2.CascadeClassifier("Haar Cascade/haarcascade_frontalface_default.xml")

cap = cv2.VideoCapture(0)

while cap.isOpened():
    _, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) #Haar Cascade works only on gray scale
    faces = face_cascase.detectMultiScale(gray, 1.1, 4) #go back to video to understand the parameters
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 3)
        
    cv2.imshow("img", img)
    if cv2.waitKey(1) == ord("q"):
        cv2.destroyAllWindows()
        break

        
cap.release()
cv2.destroyAllWindows()
