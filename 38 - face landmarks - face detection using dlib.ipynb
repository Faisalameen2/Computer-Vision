# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
import dlib
import cv2

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("dlib/shape_predictor_68_face_landmarks.dat")

cap = cv2.VideoCapture(0)

while True:
    _,frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = detector(gray)
    for face in faces:
        #print(face) #face = x1,y1,x2,y2
        x1 = face.left()
        y1 = face.top()
        x2 = face.right()
        y2 = face.bottom()
        #cv2.rectangle(frame, (x1,y1), (x2,y2), (0,255,0), 2)
        landmarks = predictor(gray, face)
        
        for n in range(0,68): #68 is in the "dat" file name in above
            x = landmarks.part(n).x 
            y = landmarks.part(n).y
            #print(x,y) #x and y are the points "dots" in the faces
            cv2.circle(frame, (x,y), 3,(0,255,0),-1)
    
    cv2.imshow("my face", frame)
    cv2.imshow("gray face", gray)
    key = cv2.waitKey(1)
    if key == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       1 import dlib
#       2 import cv2
# ----> 4 detector = dlib.get_frontal_face_detector()
#       5 predictor = dlib.shape_predictor("dlib/shape_predictor_68_face_landmarks.dat")
#       7 cap = cv2.VideoCapture(0)
#
# AttributeError: module 'dlib' has no attribute 'get_frontal_face_detector'
